# %%
import pandas as pd 
import numpy as np

# %%
import sys
# !{sys.executable} -m pip install matplotlib seaborn
# Out:
# ...
# [notice] A new release of pip is available: 26.0.1 -> 26.1.1
# [notice] To update, run: C:\Users\adiii\AppData\Local\Programs\Python\Python312\python.exe -m pip install --upgrade pip

# %%
import matplotlib.pyplot as plt
import seaborn as sns
sns.set(style = 'whitegrid')

# %% [markdown]
# ### Handle errors during analysis

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
df =  pd.read_csv('AIML Dataset.csv')

# %% [markdown]
# ## EDA

# %%
df.head()
# Out:
#    step      type    amount     nameOrig  oldbalanceOrg  newbalanceOrig  \
# 0     1   PAYMENT   9839.64  C1231006815       170136.0       160296.36
# 1     1   PAYMENT   1864.28  C1666544295        21249.0        19384.72
# 2     1  TRANSFER    181.00  C1305486145          181.0            0.00
# 3     1  CASH_OUT    181.00   C840083671          181.0            0.00
# 4     1   PAYMENT  11668.14  C2048537720        41554.0        29885.86
#
#       nameDest  oldbalanceDest  newbalanceDest  isFraud  isFlaggedFraud
# 0  M1979787155             0.0             0.0        0               0
# 1  M2044282225             0.0             0.0        0               0
# 2   C553264065             0.0             0.0        1               0
# 3    C38997010         21182.0             0.0        1               0
# 4  M1230701703             0.0             0.0        0               0

# %%
df[['isFraud']].value_counts()
# Out:
# isFraud
# 0          6354407
# 1             8213
# Name: count, dtype: int64

# %%
df[['isFlaggedFraud']].value_counts()
# Out:
# isFlaggedFraud
# 0                 6362604
# 1                      16
# Name: count, dtype: int64

# %%
df.shape
# Out:
# (6362620, 11)

# %% [markdown]
# ### Fraud percentage

# %%
round((df['isFraud'].value_counts()[1]/df.shape[0]) * 100,2)
# Out:
# np.float64(0.13)

# %% [markdown]
# ### Transaction type by Bar chart

# %%
df['type'].value_counts().plot(kind = 'bar',title  = 'Transaction types', color =  'blue')
plt.xlabel('Transaction types')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# ### Fraud type in Transactions by Bar chart

# %%
fraud_by_type = df.groupby('type')['isFraud'].mean().sort_values(ascending =  False)
fraud_by_type.plot(kind = 'bar',title = 'fraud_by_type',color = 'Red')
plt.ylabel('Fraud Rate')
plt.show()

# %% [markdown]
# ### Amount distribution by histogram

# %%
sns.histplot(np.log1p(df["amount"]), bins=100, kde=True, color="green")
plt.title("Transaction Amount Distribution (log scale)")
plt.xlabel("Log(Amount + 1)")
plt.show()

# %% [markdown]
# ### Amount distribution under 50k based on isfraud or not by Boxplot

# %%
sns.boxplot(data = df[df['amount'] < 50000],x = 'isFraud', y = 'amount',color = 'blue')
plt.title('amount vs isfraud(filtered under 50k)')
plt.show()

# %%
df.columns
# Out:
# Index(['step', 'type', 'amount', 'nameOrig', 'oldbalanceOrg', 'newbalanceOrig',
#        'nameDest', 'oldbalanceDest', 'newbalanceDest', 'isFraud',
#        'isFlaggedFraud'],
#       dtype='str')

# %% [markdown]
# ### Difference of balance for senders and recievers

# %%
df["balanceDiffOrg"] = df["oldbalanceOrg"] - df["newbalanceOrig"]
df["balanceDiffDest"] = df["oldbalanceDest"] - df["newbalanceDest"]

# %%
(df["balanceDiffOrg"] > 0 ).sum()
# Out:
# np.int64(2874330)

# %%
(df["balanceDiffDest"] > 0 ).sum()
# Out:
# np.int64(1238864)

# %% [markdown]
# ### Fraud over Step(time) by Plot chart

# %%
frauds_per_step = df[df["isFraud"] == 1]["step"].value_counts().sort_index()
plt.plot(frauds_per_step.index , frauds_per_step.values, label="Frauds per Step",color = 'red')
plt.xlabel("Step (Time)")
plt.ylabel("Number of Frauds")
plt.title("Frauds Over Time")
plt.grid(True)
plt.show()

# %%
df.drop(columns = "step",inplace = True)

# %%
df.head(2)
# Out:
#       type   amount     nameOrig  oldbalanceOrg  newbalanceOrig     nameDest  \
# 0  PAYMENT  9839.64  C1231006815       170136.0       160296.36  M1979787155
# 1  PAYMENT  1864.28  C1666544295        21249.0        19384.72  M2044282225
#
#    oldbalanceDest  newbalanceDest  isFraud  isFlaggedFraud  balanceDiffOrg  \
# 0             0.0             0.0        0               0         9839.64
# 1             0.0             0.0        0               0         1864.28
#
#    balanceDiffDest
# 0              0.0
# 1              0.0

# %% [markdown]
# ### Find Top 10 Senders

# %%
top_senders = df["nameOrig"].value_counts().head(10)
top_senders
# Out:
# nameOrig
# C2098525306    3
# C400299098     3
# C1999539787    3
# C1065307291    3
# C545315117     3
# C1976208114    3
# C1784010646    3
# C1530544995    3
# C1902386530    3
# C1677795071    3
# Name: count, dtype: int64

# %% [markdown]
# ### Find Top 10 Receivers

# %%
top_receivers = df["nameDest"].value_counts().head(10)
top_receivers
# Out:
# nameDest
# C1286084959    113
# C985934102     109
# C665576141     105
# C2083562754    102
# C248609774     101
# C1590550415    101
# C451111351      99
# C1789550256     99
# C1360767589     98
# C1023714065     97
# Name: count, dtype: int64

# %%
df.columns
# Out:
# Index(['type', 'amount', 'nameOrig', 'oldbalanceOrg', 'newbalanceOrig',
#        'nameDest', 'oldbalanceDest', 'newbalanceDest', 'isFraud',
#        'isFlaggedFraud', 'balanceDiffOrg', 'balanceDiffDest'],
#       dtype='str')

# %% [markdown]
# ###  Corelation Matrix

# %%
corr = df[["amount","oldbalanceOrg","newbalanceOrig","oldbalanceDest","newbalanceDest","isFraud"]].corr()

corr
# Out:
#                   amount  oldbalanceOrg  newbalanceOrig  oldbalanceDest  \
# amount          1.000000      -0.002762       -0.007861        0.294137
# oldbalanceOrg  -0.002762       1.000000        0.998803        0.066243
# newbalanceOrig -0.007861       0.998803        1.000000        0.067812
# oldbalanceDest  0.294137       0.066243        0.067812        1.000000
# newbalanceDest  0.459304       0.042029        0.041837        0.976569
# isFraud         0.076688       0.010154       -0.008148       -0.005885
#
#                 newbalanceDest   isFraud
# amount                0.459304  0.076688
# oldbalanceOrg         0.042029  0.010154
# newbalanceOrig        0.041837 -0.008148
# oldbalanceDest        0.976569 -0.005885
# newbalanceDest        1.000000  0.000535
# isFraud               0.000535  1.000000

# %% [markdown]
# ### Heatmap

# %%
sns.heatmap(corr,annot=True,cmap="coolwarm",fmt=".2f")
plt.title("Correlation Matrix")
plt.show()

# %% [markdown]
# ### Accounts which becomes 0 After Transaction

# %%
zero_after_transfer = df[
    (df["oldbalanceOrg"] > 0) &
    (df["newbalanceOrig"] == 0) &
    (df["type"].isin(["TRANSFER","CASH_OUT"])) #  because  almost all frauds happened in these two transactions
]

# %%
len(zero_after_transfer)
# Out:
# 1188074

# %%
zero_after_transfer.head()
# Out:
#         type     amount     nameOrig  oldbalanceOrg  newbalanceOrig  \
# 2   TRANSFER     181.00  C1305486145          181.0             0.0
# 3   CASH_OUT     181.00   C840083671          181.0             0.0
# 15  CASH_OUT  229133.94   C905080434        15325.0             0.0
# 19  TRANSFER  215310.30  C1670993182          705.0             0.0
# 24  TRANSFER  311685.89  C1984094095        10835.0             0.0
#
#        nameDest  oldbalanceDest  newbalanceDest  isFraud  isFlaggedFraud  \
# 2    C553264065             0.0            0.00        1               0
# 3     C38997010         21182.0            0.00        1               0
# 15   C476402209          5083.0        51513.44        0               0
# 19  C1100439041         22425.0            0.00        0               0
# 24   C932583850          6267.0      2719172.89        0               0
#
#     balanceDiffOrg  balanceDiffDest
# 2            181.0             0.00
# 3            181.0         21182.00
# ...

# %%
print(df["isFraud"].value_counts())
# Out:
# isFraud
# 0    6354407
# 1       8213
# Name: count, dtype: int64

# %% [markdown]
# ## Feature Engineering and ML Model Selection

# %%
import sys
# !{sys.executable} -m pip install scikit-learn
# Out:
# ...
#   Using cached joblib-1.5.3-py3-none-any.whl.metadata (5.5 kB)
# ...
#   Using cached threadpoolctl-3.6.0-py3-none-any.whl.metadata (13 kB)
# ...
#    ---------------------------------------- 0.0/8.0 MB ? eta -:--:--
#    --------- ------------------------------ 1.8/8.0 MB 14.3 MB/s eta 0:00:01
#    ----------------------- ---------------- 4.7/8.0 MB 15.9 MB/s eta 0:00:01
#    -------------------------- ------------- 5.2/8.0 MB 11.4 MB/s eta 0:00:01
#    ------------------------------ --------- 6.0/8.0 MB 8.4 MB/s eta 0:00:01
#    --------------------------------- ------ 6.8/8.0 MB 7.8 MB/s eta 0:00:01
#    ------------------------------------- -- 7.6/8.0 MB 6.7 MB/s eta 0:00:01
#    ---------------------------------------- 8.0/8.0 MB 6.2 MB/s  0:00:01
# Using cached joblib-1.5.3-py3-none-any.whl (309 kB)
# ...
#    ---------------------------------------- 0.0/36.5 MB ? eta -:--:--
#    - -------------------------------------- 1.0/36.5 MB 5.6 MB/s eta 0:00:07
# ...

# %%
import sklearn
print(sklearn.__version__)
# Out:
# 1.8.0

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing   import StandardScaler, OneHotEncoder
from sklearn.linear_model    import LogisticRegression
from sklearn.metrics         import classification_report, confusion_matrix
from sklearn.pipeline        import Pipeline
from sklearn.compose         import ColumnTransformer

# %%
df.head()
# Out:
#        type    amount     nameOrig  oldbalanceOrg  newbalanceOrig  \
# 0   PAYMENT   9839.64  C1231006815       170136.0       160296.36
# 1   PAYMENT   1864.28  C1666544295        21249.0        19384.72
# 2  TRANSFER    181.00  C1305486145          181.0            0.00
# 3  CASH_OUT    181.00   C840083671          181.0            0.00
# 4   PAYMENT  11668.14  C2048537720        41554.0        29885.86
#
#       nameDest  oldbalanceDest  newbalanceDest  isFraud  isFlaggedFraud  \
# 0  M1979787155             0.0             0.0        0               0
# 1  M2044282225             0.0             0.0        0               0
# 2   C553264065             0.0             0.0        1               0
# 3    C38997010         21182.0             0.0        1               0
# 4  M1230701703             0.0             0.0        0               0
#
#    balanceDiffOrg  balanceDiffDest
# 0         9839.64              0.0
# 1         1864.28              0.0
# ...

# %%
 df_model = df.drop(["nameOrig","nameDest","isFlaggedFraud"],axis = 1)

# %%
df_model.head()
# Out:
#        type    amount  oldbalanceOrg  newbalanceOrig  oldbalanceDest  \
# 0   PAYMENT   9839.64       170136.0       160296.36             0.0
# 1   PAYMENT   1864.28        21249.0        19384.72             0.0
# 2  TRANSFER    181.00          181.0            0.00             0.0
# 3  CASH_OUT    181.00          181.0            0.00         21182.0
# 4   PAYMENT  11668.14        41554.0        29885.86             0.0
#
#    newbalanceDest  isFraud  balanceDiffOrg  balanceDiffDest
# 0             0.0        0         9839.64              0.0
# 1             0.0        0         1864.28              0.0
# 2             0.0        1          181.00              0.0
# 3             0.0        1          181.00          21182.0
# 4             0.0        0        11668.14              0.0

# %% [markdown]
# ### # Categorical and numerical columns

# %%
categorical = ["type"]

numeric = [
    "amount",
    "oldbalanceOrg",
    "newbalanceOrig",
    "oldbalanceDest",
    "newbalanceDest"
]

# %% [markdown]
# ### Target variable and features

# %%
y = df_model["isFraud"]

X = df_model.drop("isFraud", axis=1)

# %% [markdown]
# ### Train-test split

# %%
X_train, X_test, y_train, y_test = train_test_split(
    X,
    y,
    test_size=0.3,
    stratify=y
)

# %% [markdown]
# ### Preprocessing pipeline

# %%
preprocessor = ColumnTransformer(
    transformers=[
        ("num", StandardScaler(), numeric),
        ("cat", OneHotEncoder(drop="first"), categorical)
    ],
    remainder="drop"
)

# %%
pipeline = Pipeline([

    # Preprocessing Step
    ("prep", preprocessor),

    # Logistic Regression Model
    ("clf", LogisticRegression(
        class_weight="balanced",
        max_iter=1000
    ))
])

# %% [markdown]
# ### Training the Model

# %%
pipeline.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('prep',
#                  ColumnTransformer(transformers=[('num', StandardScaler(),
#                                                   ['amount', 'oldbalanceOrg',
#                                                    'newbalanceOrig',
#                                                    'oldbalanceDest',
#                                                    'newbalanceDest']),
#                                                  ('cat',
#                                                   OneHotEncoder(drop='first'),
#                                                   ['type'])])),
#                 ('clf',
#                  LogisticRegression(class_weight='balanced', max_iter=1000))])

# %% [markdown]
# ### Making Predictions on Test Data

# %%
y_pred = pipeline.predict(X_test)

# %% [markdown]
# ### Model Evaluation Report

# %%
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      0.95      0.97   1906322
#            1       0.02      0.94      0.04      2464
#
#     accuracy                           0.95   1908786
#    macro avg       0.51      0.94      0.51   1908786
# weighted avg       1.00      0.95      0.97   1908786

# %%
 confusion_matrix(y_test,y_pred)
# Out:
# array([[1802349,  103973],
#        [    146,    2318]])

# %% [markdown]
# ### Model Accuracy Score

# %%
pipeline.score(X_test, y_test) * 100
# Out:
# 94.54527642176755

# %%
import joblib

joblib.dump(
    pipeline,
    "fraud_detection_pipeline.pkl"
)
# Out:
# ['fraud_detection_pipeline.pkl']
